# %% [markdown]
# ### Model integration with Groq

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.3-70b-versatile")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# "Parrots are known for their remarkable ability to mimic human speech and other sounds, and there are several reasons why they do so. Here are some possible explanations:\n\n1. **Communication**: In the wild, parrots use vocalizations to communicate with each other. They may mimic other birds, animals, or even natural sounds like waterfalls or wind to convey messages, warn of predators, or attract mates. Talking is an extension of this natural behavior, allowing them to interact with their human caregivers and environment.\n2. **Social bonding**: Parrots are highly social creatures that thrive on interaction. By mimicking human speech, they may be attempting to bond with their owners, establish a connection, or even seek attention. Talking can be a way for parrots to initiate interaction, play, or receive affection.\n3. **Learning and imitation**: Parrots are renowned for their intelligence and ability to learn. They may mimic human speech simply because they find it interesting or enjoyable. By repeating words and phrases, they may be exercising their cognitive abilities, learning new sounds, and refining their vocal skills.\n4. **Attention-seeking**: Let's face it – talking parrots can be quite entertaining! Some parrots may learn to talk because they've discovered that it gets a reaction from their owners. By mimicking human speech, they may be seeking attention, treats, or praise.\n5. **Environmental influence**: Parrots are highly attuned to their environment and may pick up on the sounds and rhythms of their surroundings. If they're exposed to human speech regularly, they may begin to mimic it as a way of adapting to their environment and fitting in.\n6. **Brain structure**: Research suggests that parrots have a large brain-to-body mass ratio, which may contribute to their advanced cognitive abilities and capacity for vocal learning. The structure of their brain, particularly the syrinx (the vocal organ located at the base of the trachea), allows for a wide range of vocalizations, including mimicry of human speech.\n\nIt's essential to remember that not all parrots talk, and some species are more prone to mimicry than others. African Greys, Amazon parrots, and Macaws are known for their exceptional talking abilities, while other species, like Cockatiels and Budgies, may be less vocal.\n\nOverall, the reasons why parrots talk are complex and multifaceted, involving a combination of natural behavior, social interaction, learning, and environmental influences."

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model = "llama-3.3-70b-versatile")
response = model.invoke("Hello how are you?")
response.content
# Out:
# "Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you might have. How can I assist you today?"
