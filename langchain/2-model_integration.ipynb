# %% [markdown]
# ### Model integration with Groq

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.3-70b-versatile")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# "Parrots are known for their remarkable ability to mimic human speech and other sounds, and there are several reasons why they do so. Here are some possible explanations:\n\n1. **Communication**: In the wild, parrots use vocalizations to communicate with each other. They may mimic other birds, animals, or even natural sounds like waterfalls or wind to convey messages, warn of predators, or attract mates. Talking is an extension of this natural behavior, allowing them to interact with their human caregivers and environment.\n2. **Social bonding**: Parrots are highly social creatures that thrive on interaction. By mimicking human speech, they may be attempting to bond with their owners, establish a connection, or even seek attention. Talking can be a way for parrots to initiate interaction, play, or receive affection.\n3. **Learning and imitation**: Parrots are renowned for their intelligence and ability to learn. They may mimic human speech simply because they find it interesting or enjoyable. By repeating words and phrases, they may be exercising their cognitive abilities, learning new sounds, and refining their vocal skills.\n4. **Attention-seeking**: Let's face it – talking parrots can be quite entertaining! Some parrots may learn to talk because they've discovered that it gets a reaction from their owners. By mimicking human speech, they may be seeking attention, treats, or praise.\n5. **Environmental influence**: Parrots are highly attuned to their environment and may pick up on the sounds and rhythms of their surroundings. If they're exposed to human speech regularly, they may begin to mimic it as a way of adapting to their environment and fitting in.\n6. **Brain structure**: Research suggests that parrots have a large brain-to-body mass ratio, which may contribute to their advanced cognitive abilities and capacity for vocal learning. The structure of their brain, particularly the syrinx (the vocal organ located at the base of the trachea), allows for a wide range of vocalizations, including mimicry of human speech.\n\nIt's essential to remember that not all parrots talk, and some species are more prone to mimicry than others. African Greys, Amazon parrots, and Macaws are known for their exceptional talking abilities, while other species, like Cockatiels and Budgies, may be less vocal.\n\nOverall, the reasons why parrots talk are complex and multifaceted, involving a combination of natural behavior, social interaction, learning, and environmental influences."

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model = "llama-3.3-70b-versatile")
response = model.invoke("Hello how are you?")
response.content
# Out:
# "Hello. I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you might have. How can I assist you today?"

# %% [markdown]
# ### Streaming

# %%
for chunk in model.stream("Write me a 200 words paragraph on artificical intelligence."):

    print(chunk.text, end = "", flush=True)
# Out:
# Artificial intelligence (AI) has revolutionized the way we live, work, and interact with technology. AI refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. From virtual assistants like Siri and Alexa to self-driving cars and personalized product recommendations, AI is increasingly becoming an integral part of our daily lives. AI algorithms can analyze vast amounts of data, identify patterns, and make predictions, enabling businesses to make informed decisions and improve efficiency. Additionally, AI-powered chatbots and virtual agents are being used in customer service, healthcare, and education to provide personalized support and enhance user experiences. As AI technology continues to advance, we can expect to see even more innovative applications, such as intelligent robots, smart homes, and autonomous systems. However, the development and deployment of AI also raise important questions about ethics, job displacement, and accountability, highlighting the need for responsible AI development and regulation to ensure that the benefits of AI are shared by all. Overall, AI has the potential to transform industries and improve lives, and its impact will only continue to grow in the coming years.

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):

    print(chunk.text, end = "", flush=True)
# Out:
# Parrots have colorful feathers for several reasons, including:
#
# 1. **Communication and Expression**: Bright colors help parrots communicate with each other. Different colors can signal emotions, intentions, and social status. For example, a parrot may display bright colors to attract a mate or to warn off a rival.
# 2. **Mating and Courtship**: Vibrant colors play a crucial role in parrot courtship. Males often display their brightest colors to attract females and show off their health, strength, and genetic quality.
# 3. **Camouflage and Protection**: While it may seem counterintuitive, the bright colors of some parrots can actually serve as camouflage in their natural habitats. For example, the blue and yellow feathers of the blue-and-yellow macaw can help it blend in with the bright flowers and foliage of the tropical rainforest.
# 4. **Visual Display and Intimidation**: Parrots use their colorful feathers to intimidate rivals or predators. A brightly colored parrot may appear more formidable or threatening, which can help deter potential competitors or predators.
# 5. **Evolutionary Advantage**: The bright colors of parrots may have evolved as a result of the bird's diet, which is rich in carotenoid pigments (found in fruits, vegetables, and other plants). These pigments are responsible for the yellow, orange, and red colors in many parrots.
# 6. **Social Signaling**: Parrots use their colorful feathers to signal their social status, age, and sex. For example, some parrot species have distinctive color patterns that indicate whether a bird is juvenile or adult, male or female.
# 7. **Thermoregulation**: Some researchers suggest that the bright colors of parrots may help regulate their body temperature. The dark colors can absorb heat, while the light colors can reflect it, helping the bird maintain a stable body temperature.
#
# Overall, the colorful feathers of parrots serve multiple purposes, including communication, mating, camouflage, intimidation, and social signaling. These vibrant colors are an essential part of a parrot's behavior, ecology, and evolution.
