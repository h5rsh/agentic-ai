# %% [markdown]
# ### Model integration with Groq

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.3-70b-versatile")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# "Parrots are known for their remarkable ability to mimic human speech and other sounds, but why do they do it? The reasons behind parrot vocalizations are complex and multifaceted. Here are some possible explanations:\n\n1. **Communication and Social Bonding**: In the wild, parrots use vocalizations to communicate with each other, establishing social bonds, warning calls, and contact calls. They may mimic other birds, animals, or even environmental sounds to convey information or express emotions.\n2. **Mimicry and Learning**: Parrots are highly intelligent birds, and they have a strong desire to learn and mimic. They may learn to associate certain sounds or words with food, attention, or other rewards, which can lead to mimicry of human speech.\n3. **Attention-Seeking**: Parrots are social animals and thrive on interaction. By mimicking human speech, they may be seeking attention, affection, or play from their human caregivers.\n4. **Emotional Expression**: Parrots may use vocalizations to express emotions like happiness, excitement, or stress. They may mimic certain words or phrases to convey their emotional state or to initiate interaction.\n5. **Brain Development and Exercise**: Mimicry and vocalization may be a way for parrots to exercise their brains and develop their cognitive abilities. By learning and practicing new sounds, they may be stimulating their neural connections and strengthening their memory.\n6. **Evolutionary Advantage**: In the wild, parrots that can mimic other birds or animals may have an evolutionary advantage. For example, a parrot that can mimic a predator's call may be able to warn its flock or deter predators.\n7. **Imprinting and Socialization**: Young parrots may learn to mimic human speech by imprinting on their human caregivers. This can lead to a strong bond between the parrot and its owner, as well as a desire to communicate and interact.\n\nIt's essential to remember that every parrot is an individual, and their reasons for talking may vary. Some parrots may be more inclined to mimic human speech due to their breed, upbringing, or environment, while others may be more focused on other forms of communication.\n\nIf you're interested in teaching your parrot to talk, be sure to provide a stimulating environment, positive reinforcement, and plenty of attention and interaction. With patience, consistency, and rewards, you may be able to encourage your parrot to develop its vocal skills and become a talented talker!"

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model = "llama-3.3-70b-versatile")
response = model.invoke("Hello how are you?")
response.content
# Out:
# "Hello! I'm just a language model, so I don't have emotions or feelings like humans do, but I'm functioning properly and ready to assist you. How can I help you today? Is there something specific you'd like to talk about or ask?"

# %% [markdown]
# ### Streaming

# %%
for chunk in model.stream("Write me a 200 words paragraph on artificical intelligence."):

    print(chunk.text, end = "", flush=True)
# Out:
# Artificial intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. These systems use algorithms and data to make informed decisions, often without human intervention. AI has become increasingly prevalent in various industries, including healthcare, finance, and transportation, where it is used to analyze data, optimize processes, and improve efficiency. For instance, AI-powered chatbots are being used to provide customer support, while self-driving cars rely on AI to navigate roads and avoid accidents. Additionally, AI has the potential to revolutionize fields such as medicine, where it can help diagnose diseases and develop personalized treatment plans. However, the increasing reliance on AI also raises concerns about job displacement, bias, and accountability. As AI continues to evolve and become more sophisticated, it is essential to address these concerns and ensure that its development is aligned with human values and ethics. By doing so, we can harness the full potential of AI to improve our lives and create a better future for all. With its vast potential, AI is set to transform the world in unprecedented ways.

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):

    print(chunk.text, end = "", flush=True)
# Out:
# Parrots have colorful feathers for several reasons, including:
#
# 1. **Communication and Social Signaling**: Bright colors help parrots communicate with each other, signal their species, sex, age, and social status. Different colors can convey different messages, such as attracting a mate, warning off rivals, or signaling dominance.
# 2. **Mating and Courtship**: Vibrant colors play a crucial role in parrot courtship and mating. Males often display their brightest colors to attract females, and the intensity of these colors can indicate a male's health, genetic quality, and suitability as a mate.
# 3. **Camouflage and Defense**: While it may seem counterintuitive, some parrots' bright colors can actually serve as camouflage in their natural habitats. For example, the blue and yellow feathers of some parrots can blend in with the bright colors of tropical flowers or foliage, making it harder for predators to spot them.
# 4. **Thermoregulation**: Some research suggests that the dark colors on a parrot's back can help absorb heat, while the lighter colors on their belly can reflect it, aiding in thermoregulation.
# 5. **Evolutionary Adaptation**: The colorful feathers of parrots have evolved over time as an adaptation to their environment. The bright colors may have provided a selective advantage, such as attracting mates or deterring predators, which has driven the evolution of these traits.
# 6. **Visual Display and Expression**: Parrots use their colorful feathers to express themselves and display their emotions. They may fluff out their feathers, spread their tails, or raise their crests to signal excitement, aggression, or courtship.
#
# It's likely that the colorful feathers of parrots serve multiple purposes, and the exact reasons may vary depending on the species and individual bird. Nonetheless, their vibrant plumage is an iconic and fascinating aspect of these amazing creatures.

# %% [markdown]
# ### Batch

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])

for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers for several reasons, including:\n\n1. **Mating and Courtship**: Bright, vibrant plumage helps parrots attract mates. The more attractive and healthy the feathers, the more likely a parrot is to find a suitable partner. In many species, males have more intense coloration than females, which helps them stand out during courtship displays.\n2. **Communication and Social Status**: Colorful feathers can convey information about a parrot's identity, age, sex, and social status within a flock. Different colors may signal dominance, submission, or other social cues, helping parrots navigate their social hierarchy.\n3. **Camouflage and Warning**: Some parrot species have feathers with colors that help them blend in with their surroundings, making it easier to avoid predators. Others have bright, warning colors that signal to potential predators that they are toxic or distasteful.\n4. **Thermoregulation**: The structure and pigmentation of parrot feathers can help regulate their body temperature. Darker feathers absorb heat, while lighter feathers reflect it, which can be beneficial in hot or cold climates.\n5. **Evolutionary Adaptation**: The development of colorful feathers in parrots is thought to have evolved as a result of their diet and environment. For example, the bright colors of some parrot species may have originated as a way to signal the presence of food sources, such as fruits or flowers.\n6. **Visual Display**: Parrots use their colorful feathers to create visual displays, such as spreading their tails or wings, to intimidate rivals, attract mates, or signal alarm.\n\nOverall, the colorful feathers of parrots serve multiple purposes, including communication, mating, social status, camouflage, thermoregulation, and visual display. These functions have evolved over time to help parrots thrive in their environments and interact with other members of their species." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 380, 'prompt_tokens': 43, 'total_tokens': 423, 'completion_time': 1.10051711, 'completion_tokens_details': None, 'prompt_time': 0.002202223, 'prompt_tokens_details': None, 'queue_time': 0.162254604, 'total_time': 1.102719333}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019ec5ac-0adf-7883-ac81-16199bd4ab41-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 43, 'output_tokens': 380, 'total_tokens': 423}
# content="Airplanes fly by using a combination of four main forces: lift, weight, thrust, and drag. Here's a simplified explanation of how these forces work together to make an airplane fly:\n\n1. **Lift**: Lift is the upward force that opposes the weight of the airplane and keeps it flying. It's created by the wings, which are designed to produce a difference in air pressure above and below the wing. As the airplane moves forward, the air flows over and under the wing, creating a region of lower air pressure above the wing and a region of higher air pressure below it. This pressure difference creates an upward force called lift, which counteracts the weight of the airplane.\n2. **Weight**: Weight is the downward force that pulls the airplane towards the ground. It's the combined weight of the airplane itself, the passengers, cargo, and fuel.\n3. **Thrust**: Thrust is the forward force that propels the airplane through the air. It's created by the airplane's engines, which produce a stream of high-speed air that exits the back of the plane. As this air exits, it produces a forward force that counteracts the drag, or resistance, created by the air.\n4. **Drag**: Drag is the backward force that opposes the motion of the airplane. It's created by the air resistance that the airplane encounters as it moves forward. Drag can be minimized by streamlining the airplane's shape and using materials that reduce air resistance.\n\nWhen an airplane is in flight, the four forces are in balance:\n\n* Lift equals weight (upward force equals downward force)\n* Thrust equals drag (forward force equals backward force)\n\nThis balance allows the airplane to maintain a steady altitude and speed.\n\nHere's a step-by-step explanation of how an airplane takes off and flies:\n\n1. **Takeoff**: The airplane accelerates down the runway, gaining speed and lift. As it reaches a critical speed, the lift becomes greater than the weight, and the airplane takes off.\n2. **Climb**: The airplane continues to accelerate and climb, with the thrust overcoming the drag and the lift overcoming the weight.\n3. **Cruise**: Once the airplane reaches its cruising altitude, the thrust and drag are in balance, and the lift and weight are also in balance. The airplane maintains a steady speed and altitude.\n4. **Descent**: When the airplane begins to descend, the thrust is reduced, and the drag increases. The lift is reduced, and the weight becomes greater than the lift, causing the airplane to descend.\n\nIn summary, airplanes fly by using the four main forces of lift, weight, thrust, and drag, which work together to create a balanced and controlled flight." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 549, 'prompt_tokens': 40, 'total_tokens': 589, 'completion_time': 1.226596788, 'completion_tokens_details': None, 'prompt_time': 0.001940184, 'prompt_tokens_details': None, 'queue_time': 0.162325816, 'total_time': 1.2285369720000001}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019ec5ac-0ae2-7c40-80b3-8c409386724f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 549, 'total_tokens': 589}
# content='**Introduction to Quantum Computing**\n=====================================\n\nQuantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve using classical computers.\n\n**Key Principles of Quantum Computing**\n--------------------------------------\n\n1. **Qubits**: Quantum computing uses quantum bits or qubits, which are the fundamental units of quantum information. Qubits are unique because they can exist in multiple states simultaneously, known as a superposition.\n2. **Superposition**: Qubits can represent not just 0 or 1, but also any linear combination of 0 and 1, allowing for the processing of multiple possibilities simultaneously.\n3. **Entanglement**: Qubits can become "entangled," meaning that the state of one qubit is dependent on the state of another, even if they are separated by large distances.\n4. **Quantum gates**: Quantum gates are the quantum equivalent of logic gates in classical computing. They perform operations on qubits, such as rotation, entanglement, and measurement.\n\n**How Quantum Computing Works**\n-------------------------------\n\n1. **Quantum circuit**: A quantum circuit is a sequence of quantum gates that are applied to a set of qubits to perform a specific operation.\n2. **Quantum algorithm**: A quantum algorithm is a set of instructions that are executed on a quantum circuit to solve a specific problem.\n3. **Measurement**: The final step in a quantum computation is measurement, where the qubits are measured to obtain a classical result.\n\n**Applications of Quantum Computing**\n--------------------------------------\n\n1. **Cryptography**: Quantum computing has the potential to break certain types of classical encryption, but it can also be used to create new, quantum-resistant encryption methods.\n2. **Optimization**: Quantum computing can be used to solve complex optimization problems, such as finding the shortest path in a network or the optimal solution to a complex system.\n3. **Simulation**: Quantum computing can be used to simulate complex systems, such as molecules and materials, which can lead to breakthroughs in fields like chemistry and materials science.\n\n**Current State and Future Prospects**\n--------------------------------------\n\nQuantum computing is still in its early stages, and significant technical challenges need to be overcome before it can be widely adopted. However, many organizations, including Google, IBM, and Microsoft, are actively working on developing quantum computing technology. The potential benefits of quantum computing are vast, and it is expected to have a significant impact on various fields in the coming years.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 518, 'prompt_tokens': 40, 'total_tokens': 558, 'completion_time': 1.0719413740000001, 'completion_tokens_details': None, 'prompt_time': 0.001686076, 'prompt_tokens_details': None, 'queue_time': 0.161870454, 'total_time': 1.07362745}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019ec5ac-0ae5-7a10-bdea-0ff9127ce5aa-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 518, 'total_tokens': 558}
